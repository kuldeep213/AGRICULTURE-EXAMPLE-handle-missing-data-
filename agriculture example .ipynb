# %%
import pandas as pd
df=pd.read_csv("apy.csv",na_values='=')

# %%
df.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
df.shape
# Out:
# (246091, 7)

# %%
df.State_Name.unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir ', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana ',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
df.Crop_Year.unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2010, 1997, 1998, 1999,
#        2007, 2008, 2009, 2011, 2012, 2013, 2014, 2015], dtype=int64)

# %%
df.dtypes
# Out:
# State_Name        object
# District_Name     object
# Crop_Year          int64
# Season            object
# Crop              object
# Area             float64
# Production       float64
# dtype: object

# %%
df.Season.unique()
# Out:
# array(['Kharif     ', 'Whole Year ', 'Autumn     ', 'Rabi       ',
#        'Summer     ', 'Winter     '], dtype=object)

# %%
df.Crop.unique()
# Out:
# array(['Arecanut', 'Other Kharif pulses', 'Rice', 'Banana', 'Cashewnut',
#        'Coconut ', 'Dry ginger', 'Sugarcane', 'Sweet potato', 'Tapioca',
#        'Black pepper', 'Dry chillies', 'other oilseeds', 'Turmeric',
#        'Maize', 'Moong(Green Gram)', 'Urad', 'Arhar/Tur', 'Groundnut',
#        'Sunflower', 'Bajra', 'Castor seed', 'Cotton(lint)', 'Horse-gram',
#        'Jowar', 'Korra', 'Ragi', 'Tobacco', 'Gram', 'Wheat', 'Masoor',
#        'Sesamum', 'Linseed', 'Safflower', 'Onion', 'other misc. pulses',
#        'Samai', 'Small millets', 'Coriander', 'Potato',
#        'Other  Rabi pulses', 'Soyabean', 'Beans & Mutter(Vegetable)',
#        'Bhindi', 'Brinjal', 'Citrus Fruit', 'Cucumber', 'Grapes', 'Mango',
#        'Orange', 'other fibres', 'Other Fresh Fruits', 'Other Vegetables',
#        'Papaya', 'Pome Fruit', 'Tomato', 'Rapeseed &Mustard', 'Mesta',
#        'Cowpea(Lobia)', 'Lemon', 'Pome Granet', 'Sapota', 'Cabbage',
#        'Peas  (vegetable)', 'Niger seed', 'Bottle Gourd', 'Sannhamp',
#        'Varagu', 'Garlic', 'Ginger', 'Oilseeds total', 'Pulses total',
#        'Jute', 'Peas & beans (Pulses)', 'Blackgram', 'Paddy', 'Pineapple',
#        'Barley', 'Khesari', 'Guar seed', 'Moth',
#        'Other Cereals & Millets', 'Cond-spcs other', 'Turnip', 'Carrot',
#        'Redish', 'Arcanut (Processed)', 'Atcanut (Raw)',
#        'Cashewnut Processed', 'Cashewnut Raw', 'Cardamom', 'Rubber',
#        'Bitter Gourd', 'Drum Stick', 'Jack Fruit', 'Snak Guard',
#        'Pump Kin', 'Tea', 'Coffee', 'Cauliflower', 'Other Citrus Fruit',
#        'Water Melon', 'Total foodgrain', 'Kapas', 'Colocosia', 'Lentil',
#        'Bean', 'Jobster', 'Perilla', 'Rajmash Kholar',
#        'Ricebean (nagadal)', 'Ash Gourd', 'Beet Root', 'Lab-Lab',
#        'Ribed Guard', 'Yam', 'Apple', 'Peach', 'Pear', 'Plums', 'Litchi',
#        'Ber', 'Other Dry Fruit', 'Jute & mesta'], dtype=object)

# %%
# convert production to numeric 

pd.to_numeric(df.Production)
# Out:
# 0           2000.0
# 1              1.0
# 2            321.0
# 3            641.0
# 4            165.0
#             ...
# 246086       801.0
# 246087       463.0
# 246088     16250.0
# 246089    597899.0
# 246090        88.0
# Name: Production, Length: 246091, dtype: float64

# %%
df.Production.isnull().sum()
# Out:
# 3727

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# 1       Other Kharif pulses       2.0         1.0
# 2                      Rice     102.0       321.0
# 3                    Banana     176.0       641.0
# 4                 Cashewnut     720.0       165.0
# ...                     ...       ...         ...
# 246086                 Rice     306.0       801.0
# 246087              Sesamum     627.0       463.0
# 246088            Sugarcane     324.0     16250.0
# 246089                 Rice  279151.0    597899.0
# 246090              Sesamum     175.0        88.0
#
# [242364 rows x 7 columns]

# %%
df.Production.isnull().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (242364, 7)

# %% [markdown]
# # which state has done better ??
#
#  # go for visualization

# %%
import seaborn as sns

# %%
sns.kdeplot(df.Production)

# %%
sns.boxplot(df.Production)

# %%
sns.boxplot(df.Area)

# %%
sns.kdeplot(df.Area)

# %%
df[df.State_Name=="Karnataka"]["District_Name"].unique()
# Out:
# array(['BAGALKOT', 'BANGALORE RURAL', 'BELGAUM', 'BELLARY',
#        'BENGALURU URBAN', 'BIDAR', 'BIJAPUR', 'CHAMARAJANAGAR',
#        'CHIKBALLAPUR', 'CHIKMAGALUR', 'CHITRADURGA', 'DAKSHIN KANNAD',
#        'DAVANGERE', 'DHARWAD', 'GADAG', 'GULBARGA', 'HASSAN', 'HAVERI',
#        'KODAGU', 'KOLAR', 'KOPPAL', 'MANDYA', 'MYSORE', 'RAICHUR',
#        'RAMANAGARA', 'SHIMOGA', 'TUMKUR', 'UDUPI', 'UTTAR KANNAD',
#        'YADGIR'], dtype=object)

# %%
df.groupby(['State_Name','Crop','Crop_Year']).sum()
# Out:
#                                                      Area  Production
# State_Name                  Crop     Crop_Year
# Andaman and Nicobar Islands Arecanut 2000         4354.00     7200.00
#                                      2001         4354.00     7300.00
#                                      2002         4363.00     7350.00
#                                      2003         4379.00     6707.00
#                                      2004         4425.37     4781.05
# ...                                                   ...         ...
# West Bengal                 Wheat    2010       316808.00   874415.00
#                                      2011       315659.00   872895.00
#                                      2012       321572.00   895927.00
#                                      2013       331481.00   927837.00
#                                      2014       334640.00   939254.00
#
# [12896 rows x 2 columns]

# %%
df[df.State_Name=="West Bengal"]["Crop"].unique()
# Out:
# array(['Rice', 'Jute', 'Mesta', 'Urad', 'Gram', 'Khesari', 'Masoor',
#        'Moong(Green Gram)', 'Oilseeds total', 'Wheat', 'Arecanut',
#        'Arhar/Tur', 'Coconut ', 'Dry chillies', 'Groundnut', 'Linseed',
#        'Maize', 'Potato', 'Pulses total', 'Rapeseed &Mustard', 'Sesamum',
#        'Sugarcane', 'Turmeric', 'Dry ginger', 'Sunflower',
#        'Peas & beans (Pulses)', 'Cotton(lint)', 'Safflower', 'Garlic',
#        'Barley', 'Bajra', 'Horse-gram', 'Other Kharif pulses', 'Soyabean',
#        'Jowar', 'Niger seed', 'Sannhamp', 'Small millets', 'Tobacco',
#        'Ragi', 'Other  Rabi pulses', 'Cardamom', 'Castor seed', 'Moth'],
#       dtype=object)

# %%
df.groupby(['State_Name','Crop_Year']).sum()
# Out:
#                                              Area   Production
# State_Name                  Crop_Year
# Andaman and Nicobar Islands 2000         44518.00  89060914.00
#                             2001         41163.00  89718700.00
#                             2002         45231.40  94387137.67
#                             2003         44799.40  95296454.67
#                             2004         45308.77  87186497.63
# ...                                           ...          ...
# West Bengal                 2010       7246875.00  38308645.00
#                             2011       7755360.00  36777774.00
#                             2012       7850936.00  38918275.00
#                             2013       7999815.00  37901281.00
#                             2014       8058390.00  43584403.00
#
# [519 rows x 2 columns]

# %%
df_=df.groupby(['State_Name','Crop_Year']).sum()

# %%
df_.columns
# Out:
# Index(['Area', 'Production'], dtype='object')

# %%
df_.reset_index(inplace=True)

# %%
df_
# Out:
#                       State_Name  Crop_Year        Area   Production
# 0    Andaman and Nicobar Islands       2000    44518.00  89060914.00
# 1    Andaman and Nicobar Islands       2001    41163.00  89718700.00
# 2    Andaman and Nicobar Islands       2002    45231.40  94387137.67
# 3    Andaman and Nicobar Islands       2003    44799.40  95296454.67
# 4    Andaman and Nicobar Islands       2004    45308.77  87186497.63
# ..                           ...        ...         ...          ...
# 514                  West Bengal       2010  7246875.00  38308645.00
# 515                  West Bengal       2011  7755360.00  36777774.00
# 516                  West Bengal       2012  7850936.00  38918275.00
# 517                  West Bengal       2013  7999815.00  37901281.00
# 518                  West Bengal       2014  8058390.00  43584403.00
#
# [519 rows x 4 columns]

# %%
df_.Area
# Out:
# 0        44518.00
# 1        41163.00
# 2        45231.40
# 3        44799.40
# 4        45308.77
#           ...
# 514    7246875.00
# 515    7755360.00
# 516    7850936.00
# 517    7999815.00
# 518    8058390.00
# Name: Area, Length: 519, dtype: float64

# %%
df_[['State_Name','Crop_Year']].groupby('State_Name').count()
# Out:
#                              Crop_Year
# State_Name
# Andaman and Nicobar Islands          8
# Andhra Pradesh                      18
# Arunachal Pradesh                   18
# Assam                               18
# Bihar                               18
# Chandigarh                          13
# Chhattisgarh                        15
# Dadra and Nagar Haveli              17
# Goa                                 12
# Gujarat                             16
# Haryana                             16
# Himachal Pradesh                    12
# Jammu and Kashmir                   12
# Jharkhand                            7
# Karnataka                           18
# Kerala                              18
# Madhya Pradesh                      17
# Maharashtra                         18
# Manipur                             11
# Meghalaya                           18
# Mizoram                             13
# Nagaland                            18
# Odisha                              19
# Puducherry                          17
# Punjab                              18
# Rajasthan                           14
# Sikkim                              18
# Tamil Nadu                          17
# Telangana                           17
# Tripura                             17
# Uttar Pradesh                       18
# Uttarakhand                         15
# West Bengal                         18

# %%
df_.groupby('State_Name').count()
# Out:
#                              Crop_Year  Area  Production
# State_Name
# Andaman and Nicobar Islands          8     8           8
# Andhra Pradesh                      18    18          18
# Arunachal Pradesh                   18    18          18
# Assam                               18    18          18
# Bihar                               18    18          18
# Chandigarh                          13    13          13
# Chhattisgarh                        15    15          15
# Dadra and Nagar Haveli              17    17          17
# Goa                                 12    12          12
# Gujarat                             16    16          16
# Haryana                             16    16          16
# Himachal Pradesh                    12    12          12
# Jammu and Kashmir                   12    12          12
# Jharkhand                            7     7           7
# Karnataka                           18    18          18
# Kerala                              18    18          18
# Madhya Pradesh                      17    17          17
# Maharashtra                         18    18          18
# Manipur                             11    11          11
# Meghalaya                           18    18          18
# Mizoram                             13    13          13
# Nagaland                            18    18          18
# Odisha                              19    19          19
# Puducherry                          17    17          17
# Punjab                              18    18          18
# Rajasthan                           14    14          14
# Sikkim                              18    18          18
# Tamil Nadu                          17    17          17
# Telangana                           17    17          17
# Tripura                             17    17          17
# Uttar Pradesh                       18    18          18
# Uttarakhand                         15    15          15
# West Bengal                         18    18          18

# %%
sns.lineplot(x='Crop_Year',y="Area",data=df[df.State_Name=="Andaman and Nicobar Islands"])

# %%
sns.lineplot(x='Crop_Year',y="Area",data=df[df.State_Name=="Odisha"])

# %%
sns.lineplot(x='Crop_Year',y="Production",data=df[df.State_Name=="Odisha"])

# %%
sns.lineplot(x='Crop_Year',y="Production",data=df[df.State_Name=="Tamil Nadu"])

# %%
sns.lineplot(x='Crop_Year',y="Production",data=df,hue="State_Name")

# %%
import plotly_express as px

# %%
px.scatter(df_,x="Area",y="Production",animation_frame="Crop_Year",animation_group="State_Name",color="State_Name")
# Out:
# <div>                            <div id="e3f630e1-c3cc-4be2-afb5-b619ff1fe3c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3f630e1-c3cc-4be2-afb5-b619ff1fe3c1")) {                    Plotly.newPlot(                        "e3f630e1-c3cc-4be2-afb5-b619ff1fe3c1",                        [{"hovertemplate": "State_Name=Andaman and Nicobar Islands<br>Crop_Year=2000<br>Area=%{x}<br>Production=%{y}<extra></extra>", "ids": ["Andaman and Nicobar Islands"], "legendgroup": "Andaman and Nicobar Islands", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Andaman and Nicobar Islands", "orientation": "v", "showlegend": true, "type": "scatter", "x": [44518.0], "xaxis": "x", "y": [89060914.0], "yaxis": "y"}, {"hovertemplate": "State_Name=Andhra Pradesh<br>Crop_Year=2000<br>Area=%{x}<br>Production=%{y}<extra></extra>", "ids": ["Andhra Pradesh"], "legendgroup": "Andhra Pradesh", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Andhra Pradesh", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7587007.0], "xaxis": "x", "y": [1109120354.0], "yaxis": "y"}, {"hovertemplate": "State_Name=Arunachal Pradesh<br>Crop_Year=2000<br>Area=%{x}<br>Production=%{y}<extra></extra>", "ids": ["Arunachal Pradesh"], "legendgroup": "Arunachal Pradesh", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "Arunachal Pradesh", "orientation": "v", "showlegend": true, "type": "scatter", "x": [227056.0], "xaxis": "x", "y": [332942.0], "yaxis": "y"}, {"hovertemplate": "State_Name=Assam<br>Crop_Year=2000<br>Area=%{x}<br>Production=%{y}<extra></extra>", "ids": ["Assam"], "legendgroup": "Assam", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "Assam", "orientation": "v", "showlegend": true, "type": "scatter", "x": [3535814.0], "xaxis": "x", "y": [143323978.0], "yaxis": "y"}, {"hovertemplate": "State_Name=Bihar<br>Crop_Year=2000<br>Area=%{x}<br>Production=%{y}<extra></extra>", "ids": ["Bihar"], "legendgroup": "Bihar", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "Bihar", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7739479.0], "xaxis": "x", "y": [19470553.1], "yaxis": "y"}, {"hovertemplate": "State_Name=Chandigarh<br>Crop_Year=2000<br>Area=%{x}<br>Production=%{y}<extra></extra>", "ids": ["Chandigarh"], "legendgroup": "Chandigarh", "marker": {"color": "#19d3f3", "symbol": "circle"}, "mode": "markers", "name": "Chandigarh", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1206.0], "xaxis": "x", "y": [6513.5], "yaxis": "y"}, {"hovertemplate": "State_Name=Chhattisgarh<br>Crop_Year=2000<br>Area=%{x}<br>Production=%{y}<extra></extra>", "ids": ["Chhattisgarh"], "legendgroup": "Chhattisgarh", "marker": {"color": "#FF6692", "symbol": "circle"}, "mode": "markers", "name": "Chhattisgarh", "orientation": "v", "showlegend": true, "type": "scatter", "x": [5224956.0], "xaxis": "x", "y": [3125107.0], "yaxis": "y"}, {"hovertemplate": "State_Name=Dadra and Nagar Haveli<br>Crop_Year=2000<br>Area=%{x}<br>Production=%{y}<extra></extra>", "ids": ["Dadra and Nagar Haveli"], "legendgroup": "Dadra and Nagar Haveli", "marker": {"color": "#B6E880", "symbol": "circle"}, "mode": "markers", "name": "Dadra and Nagar Haveli", "orientation": "v", "showlegend": true, "type": "scatter", "x": [26912.0], "xaxis": "x", "y": [132505.0], "yaxis": "y"}, {"hovertemplate": "State_Name=Gujarat<br>Crop_Year=2000<br>Area=%{x}<br>Production=%{y}<extra></extra>", "ids": ["Gujarat"], "legendgroup": "Gujarat", "marker": {"color": "#FECB52", "symbol": "circle"}, "mode": "markers", "name": "Gujarat", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8062900.0], "xaxis": "x", ...

# %%
df_.sort_values('Crop_Year',inplace=True)

# %%
df_
# Out:
#             State_Name  Crop_Year        Area   Production
# 271            Manipur       1997       206.0        412.0
# 26   Arunachal Pradesh       1997    229118.0     267148.0
# 253        Maharashtra       1997  12847691.0   11641856.0
# 125                Goa       1997     35823.0      72538.0
# 468      Uttar Pradesh       1997  39111804.0  192027165.0
# ..                 ...        ...         ...          ...
# 450         Telangana        2014   4964539.0   15806094.0
# 467            Tripura       2014    285642.0     822366.0
# 485      Uttar Pradesh       2014  24147470.0  199418844.0
# 416             Sikkim       2015     65853.0     103416.0
# 349             Odisha       2015   4534445.0    6831648.7
#
# [519 rows x 4 columns]

# %%
df[(df.State_Name=="Kerala") &(df.Crop_Year == 2000)].sort_values('Production')
# Out:
#        State_Name       District_Name  Crop_Year       Season      Crop  \
# 99868      Kerala            KOTTAYAM       2000  Kharif        Sesamum
# 100437     Kerala          MALAPPURAM       2000  Kharif           Ragi
# 99567      Kerala              KOLLAM       2000  Summer           Rice
# 98946      Kerala              KANNUR       2000  Kharif        Sesamum
# 98604      Kerala              IDUKKI       2000  Kharif           Ragi
# ...           ...                 ...        ...          ...       ...
# 101702     Kerala            THRISSUR       2000  Whole Year   Coconut
# 98953      Kerala              KANNUR       2000  Whole Year   Coconut
# 100445     Kerala          MALAPPURAM       2000  Whole Year   Coconut
# 101425     Kerala  THIRUVANANTHAPURAM       2000  Whole Year   Coconut
# 100162     Kerala           KOZHIKODE       2000  Whole Year   Coconut
#
#             Area   Production
# 99868        6.0          1.0
# 100437       4.0          3.0
# 99567        4.0          4.0
# 98946       10.0          6.0
# 98604        8.0          7.0
# ...          ...          ...
# 101702   89472.0  540000000.0
# 98953    96975.0  621000000.0
# 100445  110378.0  626000000.0
# 101425   88663.0  635000000.0
# 100162  128739.0  903000000.0
#
# [203 rows x 7 columns]

# %%
df_=df[df.Crop.isin(['Rice','Wheat','Maize','Ragi'])].groupby(['State_Name','Crop_Year']).sum()

# %%
df_.reset_index(inplace=True)

# %%
df_
# Out:
#                       State_Name  Crop_Year        Area   Production
# 0    Andaman and Nicobar Islands       2000    10881.00     32184.00
# 1    Andaman and Nicobar Islands       2001     9801.00     27333.00
# 2    Andaman and Nicobar Islands       2002    10885.00     32111.66
# 3    Andaman and Nicobar Islands       2003    10561.37     30850.87
# 4    Andaman and Nicobar Islands       2004    10734.92     29192.23
# ..                           ...        ...         ...          ...
# 513                  West Bengal       2010  5361309.00  14630175.00
# 514                  West Bengal       2011  5855620.00  15851031.00
# 515                  West Bengal       2012  5898997.00  16315137.00
# 516                  West Bengal       2013  5999179.00  16936255.00
# 517                  West Bengal       2014  6023075.00  17527428.00
#
# [518 rows x 4 columns]

# %%
px.scatter(df_,x="Area",y="Production",animation_frame="Crop_Year",animation_group="State_Name",color="State_Name")
# Out:
# <div>                            <div id="8b88bf92-e432-47e0-a38d-fa8005634a38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b88bf92-e432-47e0-a38d-fa8005634a38")) {                    Plotly.newPlot(                        "8b88bf92-e432-47e0-a38d-fa8005634a38",                        [{"hovertemplate": "State_Name=Andaman and Nicobar Islands<br>Crop_Year=2000<br>Area=%{x}<br>Production=%{y}<extra></extra>", "ids": ["Andaman and Nicobar Islands"], "legendgroup": "Andaman and Nicobar Islands", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Andaman and Nicobar Islands", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10881.0], "xaxis": "x", "y": [32184.0], "yaxis": "y"}, {"hovertemplate": "State_Name=Andhra Pradesh<br>Crop_Year=2000<br>Area=%{x}<br>Production=%{y}<extra></extra>", "ids": ["Andhra Pradesh"], "legendgroup": "Andhra Pradesh", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Andhra Pradesh", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2853487.0], "xaxis": "x", "y": [8440370.0], "yaxis": "y"}, {"hovertemplate": "State_Name=Arunachal Pradesh<br>Crop_Year=2000<br>Area=%{x}<br>Production=%{y}<extra></extra>", "ids": ["Arunachal Pradesh"], "legendgroup": "Arunachal Pradesh", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "Arunachal Pradesh", "orientation": "v", "showlegend": true, "type": "scatter", "x": [161427.0], "xaxis": "x", "y": [191213.0], "yaxis": "y"}, {"hovertemplate": "State_Name=Assam<br>Crop_Year=2000<br>Area=%{x}<br>Production=%{y}<extra></extra>", "ids": ["Assam"], "legendgroup": "Assam", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "Assam", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2736719.0], "xaxis": "x", "y": [4098754.0], "yaxis": "y"}, {"hovertemplate": "State_Name=Bihar<br>Crop_Year=2000<br>Area=%{x}<br>Production=%{y}<extra></extra>", "ids": ["Bihar"], "legendgroup": "Bihar", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "Bihar", "orientation": "v", "showlegend": true, "type": "scatter", "x": [6367134.0], "xaxis": "x", "y": [11394464.0], "yaxis": "y"}, {"hovertemplate": "State_Name=Chandigarh<br>Crop_Year=2000<br>Area=%{x}<br>Production=%{y}<extra></extra>", "ids": ["Chandigarh"], "legendgroup": "Chandigarh", "marker": {"color": "#19d3f3", "symbol": "circle"}, "mode": "markers", "name": "Chandigarh", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1020.0], "xaxis": "x", "y": [4225.0], "yaxis": "y"}, {"hovertemplate": "State_Name=Chhattisgarh<br>Crop_Year=2000<br>Area=%{x}<br>Production=%{y}<extra></extra>", "ids": ["Chhattisgarh"], "legendgroup": "Chhattisgarh", "marker": {"color": "#FF6692", "symbol": "circle"}, "mode": "markers", "name": "Chhattisgarh", "orientation": "v", "showlegend": true, "type": "scatter", "x": [3952137.0], "xaxis": "x", "y": [2577081.0], "yaxis": "y"}, {"hovertemplate": "State_Name=Dadra and Nagar Haveli<br>Crop_Year=2000<br>Area=%{x}<br>Production=%{y}<extra></extra>", "ids": ["Dadra and Nagar Haveli"], "legendgroup": "Dadra and Nagar Haveli", "marker": {"color": "#B6E880", "symbol": "circle"}, "mode": "markers", "name": "Dadra and Nagar Haveli", "orientation": "v", "showlegend": true, "type": "scatter", "x": [17353.0], "xaxis": "x", "y": [32092.0], "yaxis": "y"}, {"hovertemplate": "State_Name=Gujarat<br>Crop_Year=2000<br>Area=%{x}<br>Production=%{y}<extra></extra>", "ids": ["Gujarat"], "legendgroup": "Gujarat", "marker": {"color": "#FECB52", "symbol": "circle"}, "mode": "markers", "name": "Gujarat", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1276000.0], "xaxis": "x", "y": [14 ...

# %%
df_['Efficiency']=df_['Production']/df_['Area']

# %%
df_
# Out:
#                       State_Name  Crop_Year        Area   Production  \
# 0    Andaman and Nicobar Islands       2000    10881.00     32184.00
# 1    Andaman and Nicobar Islands       2001     9801.00     27333.00
# 2    Andaman and Nicobar Islands       2002    10885.00     32111.66
# 3    Andaman and Nicobar Islands       2003    10561.37     30850.87
# 4    Andaman and Nicobar Islands       2004    10734.92     29192.23
# ..                           ...        ...         ...          ...
# 513                  West Bengal       2010  5361309.00  14630175.00
# 514                  West Bengal       2011  5855620.00  15851031.00
# 515                  West Bengal       2012  5898997.00  16315137.00
# 516                  West Bengal       2013  5999179.00  16936255.00
# 517                  West Bengal       2014  6023075.00  17527428.00
#
#      Efficiency
# 0      2.957816
# 1      2.788797
# 2      2.950084
# 3      2.921105
# 4      2.719371
# ..          ...
# 513    2.728844
# 514    2.706977
# 515    2.765748
# 516    2.823095
# 517    2.910046
#
# [518 rows x 5 columns]

# %%
px.scatter(df_,x="Area",y="Efficiency",size='Production',animation_frame="Crop_Year",animation_group="State_Name",color="State_Name")
# Out:
# <div>                            <div id="7e57820a-982a-4bd4-9ffb-d9eaf39d256a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e57820a-982a-4bd4-9ffb-d9eaf39d256a")) {                    Plotly.newPlot(                        "7e57820a-982a-4bd4-9ffb-d9eaf39d256a",                        [{"hovertemplate": "State_Name=Andaman and Nicobar Islands<br>Crop_Year=2000<br>Area=%{x}<br>Efficiency=%{y}<br>Production=%{marker.size}<extra></extra>", "ids": ["Andaman and Nicobar Islands"], "legendgroup": "Andaman and Nicobar Islands", "marker": {"color": "#636efa", "size": [32184.0], "sizemode": "area", "sizeref": 118901.4175, "symbol": "circle"}, "mode": "markers", "name": "Andaman and Nicobar Islands", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10881.0], "xaxis": "x", "y": [2.957816377171216], "yaxis": "y"}, {"hovertemplate": "State_Name=Andhra Pradesh<br>Crop_Year=2000<br>Area=%{x}<br>Efficiency=%{y}<br>Production=%{marker.size}<extra></extra>", "ids": ["Andhra Pradesh"], "legendgroup": "Andhra Pradesh", "marker": {"color": "#EF553B", "size": [8440370.0], "sizemode": "area", "sizeref": 118901.4175, "symbol": "circle"}, "mode": "markers", "name": "Andhra Pradesh", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2853487.0], "xaxis": "x", "y": [2.9579142992415948], "yaxis": "y"}, {"hovertemplate": "State_Name=Arunachal Pradesh<br>Crop_Year=2000<br>Area=%{x}<br>Efficiency=%{y}<br>Production=%{marker.size}<extra></extra>", "ids": ["Arunachal Pradesh"], "legendgroup": "Arunachal Pradesh", "marker": {"color": "#00cc96", "size": [191213.0], "sizemode": "area", "sizeref": 118901.4175, "symbol": "circle"}, "mode": "markers", "name": "Arunachal Pradesh", "orientation": "v", "showlegend": true, "type": "scatter", "x": [161427.0], "xaxis": "x", "y": [1.1845168404294202], "yaxis": "y"}, {"hovertemplate": "State_Name=Assam<br>Crop_Year=2000<br>Area=%{x}<br>Efficiency=%{y}<br>Production=%{marker.size}<extra></extra>", "ids": ["Assam"], "legendgroup": "Assam", "marker": {"color": "#ab63fa", "size": [4098754.0], "sizemode": "area", "sizeref": 118901.4175, "symbol": "circle"}, "mode": "markers", "name": "Assam", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2736719.0], "xaxis": "x", "y": [1.4976890210503893], "yaxis": "y"}, {"hovertemplate": "State_Name=Bihar<br>Crop_Year=2000<br>Area=%{x}<br>Efficiency=%{y}<br>Production=%{marker.size}<extra></extra>", "ids": ["Bihar"], "legendgroup": "Bihar", "marker": {"color": "#FFA15A", "size": [11394464.0], "sizemode": "area", "sizeref": 118901.4175, "symbol": "circle"}, "mode": "markers", "name": "Bihar", "orientation": "v", "showlegend": true, "type": "scatter", "x": [6367134.0], "xaxis": "x", "y": [1.789575027005871], "yaxis": "y"}, {"hovertemplate": "State_Name=Chandigarh<br>Crop_Year=2000<br>Area=%{x}<br>Efficiency=%{y}<br>Production=%{marker.size}<extra></extra>", "ids": ["Chandigarh"], "legendgroup": "Chandigarh", "marker": {"color": "#19d3f3", "size": [4225.0], "sizemode": "area", "sizeref": 118901.4175, "symbol": "circle"}, "mode": "markers", "name": "Chandigarh", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1020.0], "xaxis": "x", "y": [4.142156862745098], "yaxis": "y"}, {"hovertemplate": "State_Name=Chhattisgarh<br>Crop_Year=2000<br>Area=%{x}<br>Efficiency=%{y}<br>Production=%{marker.size}<extra></extra>", "ids": ["Chhattisgarh"], "legendgroup": "Chhattisgarh", "marker": {"color": "#FF6692", "size": [2577081.0], "sizemode": "area", "sizeref": 118901.4175, "symbol": "circle"}, "mode": "markers", "name": "Chhattisgarh", "orientation": "v", "showlegend": true, "type": "scatter", "x": [3952137.0], "xaxis": "x", "y": [0.6520727899867844], "yaxis": "y"}, {"hovertemplate": "State_Name=Dadra and Nag ...

# %%
px.scatter(df_,x="Area",y="Efficiency",size='Production',animation_frame="Crop_Year",animation_group="State_Name",color="State_Name",range_y=[0.75,5],range_x=[-1E6,20E6])
# Out:
# <div>                            <div id="7828bfb3-c644-4a1c-855f-4ff990747a94" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7828bfb3-c644-4a1c-855f-4ff990747a94")) {                    Plotly.newPlot(                        "7828bfb3-c644-4a1c-855f-4ff990747a94",                        [{"hovertemplate": "State_Name=Andaman and Nicobar Islands<br>Crop_Year=2000<br>Area=%{x}<br>Efficiency=%{y}<br>Production=%{marker.size}<extra></extra>", "ids": ["Andaman and Nicobar Islands"], "legendgroup": "Andaman and Nicobar Islands", "marker": {"color": "#636efa", "size": [32184.0], "sizemode": "area", "sizeref": 118901.4175, "symbol": "circle"}, "mode": "markers", "name": "Andaman and Nicobar Islands", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10881.0], "xaxis": "x", "y": [2.957816377171216], "yaxis": "y"}, {"hovertemplate": "State_Name=Andhra Pradesh<br>Crop_Year=2000<br>Area=%{x}<br>Efficiency=%{y}<br>Production=%{marker.size}<extra></extra>", "ids": ["Andhra Pradesh"], "legendgroup": "Andhra Pradesh", "marker": {"color": "#EF553B", "size": [8440370.0], "sizemode": "area", "sizeref": 118901.4175, "symbol": "circle"}, "mode": "markers", "name": "Andhra Pradesh", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2853487.0], "xaxis": "x", "y": [2.9579142992415948], "yaxis": "y"}, {"hovertemplate": "State_Name=Arunachal Pradesh<br>Crop_Year=2000<br>Area=%{x}<br>Efficiency=%{y}<br>Production=%{marker.size}<extra></extra>", "ids": ["Arunachal Pradesh"], "legendgroup": "Arunachal Pradesh", "marker": {"color": "#00cc96", "size": [191213.0], "sizemode": "area", "sizeref": 118901.4175, "symbol": "circle"}, "mode": "markers", "name": "Arunachal Pradesh", "orientation": "v", "showlegend": true, "type": "scatter", "x": [161427.0], "xaxis": "x", "y": [1.1845168404294202], "yaxis": "y"}, {"hovertemplate": "State_Name=Assam<br>Crop_Year=2000<br>Area=%{x}<br>Efficiency=%{y}<br>Production=%{marker.size}<extra></extra>", "ids": ["Assam"], "legendgroup": "Assam", "marker": {"color": "#ab63fa", "size": [4098754.0], "sizemode": "area", "sizeref": 118901.4175, "symbol": "circle"}, "mode": "markers", "name": "Assam", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2736719.0], "xaxis": "x", "y": [1.4976890210503893], "yaxis": "y"}, {"hovertemplate": "State_Name=Bihar<br>Crop_Year=2000<br>Area=%{x}<br>Efficiency=%{y}<br>Production=%{marker.size}<extra></extra>", "ids": ["Bihar"], "legendgroup": "Bihar", "marker": {"color": "#FFA15A", "size": [11394464.0], "sizemode": "area", "sizeref": 118901.4175, "symbol": "circle"}, "mode": "markers", "name": "Bihar", "orientation": "v", "showlegend": true, "type": "scatter", "x": [6367134.0], "xaxis": "x", "y": [1.789575027005871], "yaxis": "y"}, {"hovertemplate": "State_Name=Chandigarh<br>Crop_Year=2000<br>Area=%{x}<br>Efficiency=%{y}<br>Production=%{marker.size}<extra></extra>", "ids": ["Chandigarh"], "legendgroup": "Chandigarh", "marker": {"color": "#19d3f3", "size": [4225.0], "sizemode": "area", "sizeref": 118901.4175, "symbol": "circle"}, "mode": "markers", "name": "Chandigarh", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1020.0], "xaxis": "x", "y": [4.142156862745098], "yaxis": "y"}, {"hovertemplate": "State_Name=Chhattisgarh<br>Crop_Year=2000<br>Area=%{x}<br>Efficiency=%{y}<br>Production=%{marker.size}<extra></extra>", "ids": ["Chhattisgarh"], "legendgroup": "Chhattisgarh", "marker": {"color": "#FF6692", "size": [2577081.0], "sizemode": "area", "sizeref": 118901.4175, "symbol": "circle"}, "mode": "markers", "name": "Chhattisgarh", "orientation": "v", "showlegend": true, "type": "scatter", "x": [3952137.0], "xaxis": "x", "y": [0.6520727899867844], "yaxis": "y"}, {"hovertemplate": "State_Name=Dadra and Nag ...
